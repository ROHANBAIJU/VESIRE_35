# %%
# !nvidia-smi
# Out:
# Thu Apr 25 06:23:50 2024
# +---------------------------------------------------------------------------------------+
# | NVIDIA-SMI 535.104.05             Driver Version: 535.104.05   CUDA Version: 12.2     |
# |-----------------------------------------+----------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |         Memory-Usage | GPU-Util  Compute M. |
# |                                         |                      |               MIG M. |
# |=========================================+======================+======================|
# |   0  Tesla T4                       Off | 00000000:00:04.0 Off |                    0 |
# | N/A   58C    P8              10W /  70W |      0MiB / 15360MiB |      0%      Default |
# |                                         |                      |                  N/A |
# ...

# %%
# !pip install ultralytics
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 723.1/723.1 kB 9.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.7/23.7 MB 69.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 823.6/823.6 kB 55.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.1/14.1 MB 87.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 731.7/731.7 MB 1.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 410.6/410.6 MB 3.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 121.6/121.6 MB 14.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.5/56.5 MB 30.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 124.2/124.2 MB 7.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 196.0/196.0 MB 4.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 166.0/166.0 MB 10.8 MB/s eta 0:00:00
# ...

# %%
## connecting to the google drive

from google.colab import drive
drive.mount('/content/drive')

# %%
import ultralytics
ultralytics.checks()
# Out:
# Ultralytics YOLOv8.1.26 🚀 Python-3.10.12 torch-2.1.0+cu121 CUDA:0 (Tesla V100-SXM2-16GB, 16151MiB)
# Setup complete ✅ (8 CPUs, 51.0 GB RAM, 26.4/201.2 GB disk)

# %%
# !yolo task=detect mode=train model=yolov8l.pt data="/content/drive/MyDrive/ObjectdetectionData/custom.yaml" epochs=100 imgsz=640 batch=8 project="/content/drive/MyDrive/ObjectdetectionData/training_results" name=resultsfinalLarge
# Out:
# ...
# 100% 83.7M/83.7M [00:01<00:00, 49.2MB/s]
# Ultralytics YOLOv8.1.26 🚀 Python-3.10.12 torch-2.1.0+cu121 CUDA:0 (Tesla V100-SXM2-16GB, 16151MiB)
# ...

# %%
# !ls /content/drive/MyDrive/ObjectdetectionData/training_results/resultsfinalLarge
# Out:
# args.yaml					    R_curve.png		  val_batch0_labels.jpg
# confusion_matrix_normalized.png			    results.csv		  val_batch0_pred.jpg
# confusion_matrix.png				    results.png		  val_batch1_labels.jpg
# events.out.tfevents.1710170440.8db09d7a17f1.2956.0  train_batch0.jpg	  val_batch1_pred.jpg
# F1_curve.png					    train_batch1.jpg	  val_batch2_labels.jpg
# labels_correlogram.jpg				    train_batch2.jpg	  val_batch2_pred.jpg
# labels.jpg					    train_batch88470.jpg  weights
# P_curve.png					    train_batch88471.jpg
# PR_curve.png					    train_batch88472.jpg

# %%
from IPython.display import Image

image_path = '/content/drive/MyDrive/ObjectdetectionData/training_results/resultsfinalLarge/confusion_matrix.png'
Image(filename=image_path, width=600)

# %%
image_path = '/content/drive/MyDrive/ObjectdetectionData/training_results/resultsfinalLarge/results.png'
Image(filename=image_path, width=600)

# %%
image_path = '/content/drive/MyDrive/ObjectdetectionData/training_results/resultsfinalLarge/train_batch88470.jpg'
Image(filename=image_path, width =600)

# %%
# !yolo task=detect mode=val model="/content/drive/MyDrive/ObjectdetectionData/training_results/resultsfinalLarge/weights/best.pt" data=/content/drive/MyDrive/ObjectdetectionData/custom.yaml
# Out:
# Ultralytics YOLOv8.1.37 🚀 Python-3.10.12 torch-2.2.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 268 layers, 43617402 parameters, 0 gradients, 164.9 GFLOPs
# ...
# 100% 755k/755k [00:00<00:00, 4.83MB/s]
# val: Scanning /content/drive/MyDrive/ObjectdetectionData/data/labels/val.cache... 907 images, 0 backgrounds, 0 corrupt: 100% 907/907 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 57/57 [00:54<00:00,  1.05it/s]
#                    all        907       1237      0.857      0.781       0.87      0.734
#          Apple Healthy        907        156      0.927      0.891      0.952      0.765
#        Apple Rust Leaf        907         85      0.921      0.828      0.912      0.788
#        Apple Scab Leaf        907         49      0.909          1      0.994      0.915
#     BellPepper Healthy        907        136      0.814     0.0515      0.422      0.261
# ...

# %% [markdown]
# ## **Inference on Test images**

# %%
# !yolo task=detect mode=predict model="/content/drive/MyDrive/ObjectdetectionData/training_results/resultsfinalLarge/weights/best.pt" conf=0.25 source="/content/drive/MyDrive/ObjectdetectionData/test/images" save=True
# Out:
# Ultralytics YOLOv8.1.37 🚀 Python-3.10.12 torch-2.2.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 268 layers, 43617402 parameters, 0 gradients, 164.9 GFLOPs
#
# image 1/103 /content/drive/MyDrive/ObjectdetectionData/test/images/1116_bell_pepper-leaf_0021_jpg.rf.d3e1fe2a24afa41d283b21ec2096dd70.jpg: 640x640 4 Apple Healthys, 1 BellPepper Healthy, 1 Tomato Bacterial Spot, 62.9ms
# image 2/103 /content/drive/MyDrive/ObjectdetectionData/test/images/1120_bell_pepper-leaf_0025_jpg.rf.28211f9a50c69d41cb7bbab93e67a1b5.jpg: 640x640 1 BellPepper Leaf Spot, 2 Tomato Bacterial Spots, 63.0ms
# image 3/103 /content/drive/MyDrive/ObjectdetectionData/test/images/1124_bell_pepper-leaf_0029_jpg.rf.48a3ce711104516b1b229f919dec5722.jpg: 640x640 1 Tomato Healthy, 63.0ms
# image 4/103 /content/drive/MyDrive/ObjectdetectionData/test/images/1127_bell_pepper-leaf_0032_jpg.rf.534398cf6d10f6c633d2dda83dff60ed.jpg: 640x640 3 Apple Healthys, 62.9ms
# ...

# %%
# !cp -r /content/runs/detect/predict /content/drive/MyDrive/ObjectdetectionData/test_results
